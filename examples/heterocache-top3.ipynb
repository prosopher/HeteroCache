# %%
! rm -rf HeteroCache
! git clone https://github.com/prosopher/HeteroCache
! cd HeteroCache ; pip install -r requirements.txt
# Out:
# Cloning into 'HeteroCache'...
# remote: Enumerating objects: 228, done.
# remote: Counting objects: 100% (228/228), done.
# remote: Compressing objects: 100% (131/131), done.
# remote: Total 228 (delta 129), reused 192 (delta 93), pack-reused 0 (from 0)
# Receiving objects: 100% (228/228), 185.49 KiB | 3.57 MiB/s, done.
# Resolving deltas: 100% (129/129), done.
# ...

# %%
! cd HeteroCache ; python train.py heterocache --top-layers-to-translate 3
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2026-03-10 08:03:16,693 | INFO | Starting training
# ...

# %%
! cd HeteroCache ; python eval.py heterocache --checkpoint-path outputs/heterocache_20260310_080316/final_checkpoint.pt
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2026-03-10 08:16:32,871 | INFO | Starting evaluation
# 2026-03-10 08:16:32,872 | INFO | checkpoint_path=outputs/heterocache_20260310_080316/final_checkpoint.pt
# ...
