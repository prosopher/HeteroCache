# %%
! git clone https://github.com/prosopher/HeteroCache
! cd HeteroCache ; pip install -r requirements.txt
# Out:
# Cloning into 'HeteroCache'...
# remote: Enumerating objects: 209, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (122/122), done.
# remote: Total 209 (delta 117), reused 175 (delta 83), pack-reused 0 (from 0)
# Receiving objects: 100% (209/209), 177.96 KiB | 2.62 MiB/s, done.
# Resolving deltas: 100% (117/117), done.
# Requirement already satisfied: transformers==4.35.2 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (4.35.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (3.20.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (0.36.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (2025.11.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (2.32.4)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (0.15.2)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers==4.35.2->-r requirements.txt (line 1)) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2->-r requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers==4.35.2->-r requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.2->-r requirements.txt (line 1)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.2->-r requirements.txt (line 1)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.2->-r requirements.txt (line 1)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->transformers==4.35.2->-r requirements.txt (line 1)) (2026.1.4)

# %%
! cd HeteroCache ; python train.py heterocache
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2026-03-10 06:35:38,856 | INFO | Starting training
# 2026-03-10 06:35:38,856 | INFO | train_config={'alg': 'heterocache', 'output_root': 'outputs', 'timestamp': '20260310_063538', 'output_dir': 'outputs/heterocache_20260310_063538', 'config_path': 'outputs/heterocache_20260310_063538/train_config.json', 'log_path': 'outputs/heterocache_20260310_063538/train.log', 'checkpoint_path': 'outputs/heterocache_20260310_063538/final_checkpoint.pt', 'model_a_id': 'gpt2', 'model_b_id': 'gpt2-medium', 'max_steps': 500, 'batch_size': 1, 'grad_accum_steps': 16, 'total_tokens': 128, 'prefix_tokens': 64, 'learning_rate': 0.0001, 'weight_decay': 0.01, 'warmup_steps': 50, 'grad_clip_norm': 1.0, 'log_every': 25, 'seed': 42, 'shuffle_buffer': 50000, 'top_layers_to_translate': 12, 'translator_dim': 1024, 'translator_heads': 16, 'translator_depth': 2, 'translator_mlp_ratio': 2, 'train_directions': 'B_to_A', 'device': 'cuda', 'dtype': 'float32'}
# 2026-03-10 06:35:38,856 | INFO | train_directions=['B_to_A']
# 2026-03-10 06:35:38,856 | INFO | [Setup] device=cuda
# 2026-03-10 06:35:38,856 | INFO | [Setup] loading models: A=gpt2, B=gpt2-medium
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 2026-03-10 06:35:49,172 | INFO | [Setup] full model specs
# 2026-03-10 06:35:49,172 | INFO |   A: layers=12, hidden=768, heads=12
# 2026-03-10 06:35:49,172 | INFO |   B: layers=24, hidden=1024, heads=16
# 2026-03-10 06:35:49,173 | INFO | [Setup] top_layers_to_translate = 12
# 2026-03-10 06:35:49,174 | INFO | [Setup] trainable translator params = 447,375,360
# Training:   0%|                                         | 0/500 [00:00<?, ?it/s]
# Resolving data files:   0%|                              | 0/80 [00:00<?, ?it/s]
# Resolving data files:   1%|▎                     | 1/80 [00:00<00:13,  6.03it/s]
# Resolving data files: 100%|████████████████████| 80/80 [00:00<00:00, 266.71it/s]
#
# Resolving data files: 100%|██████████████████| 80/80 [00:00<00:00, 30393.51it/s]
# Training:   0%|                               | 1/500 [00:16<2:17:32, 16.54s/it]Token indices sequence length is longer than the specified maximum sequence length for this model (1199 > 1024). Running this sequence through the model will result in indexing errors
# Training:   5%|▎     | 24/500 [01:22<21:50,  2.75s/it, loss=6.8962, lr=5.00e-05]2026-03-10 06:37:12,547 | INFO | [Step 0025] total_suffix_lm_loss=6.8962 | lr=5.00e-05 | train_directions=B_to_A
# Training:  10%|▌     | 49/500 [02:30<20:32,  2.73s/it, loss=4.4039, lr=1.00e-04]2026-03-10 06:38:21,209 | INFO | [Step 0050] total_suffix_lm_loss=4.4039 | lr=1.00e-04 | train_directions=B_to_A
# Training:  15%|▉     | 74/500 [03:40<19:34,  2.76s/it, loss=4.1075, lr=9.92e-05]2026-03-10 06:39:30,230 | INFO | [Step 0075] total_suffix_lm_loss=4.1075 | lr=9.92e-05 | train_directions=B_to_A
# Training:  20%|█▏    | 99/500 [04:48<18:23,  2.75s/it, loss=3.9408, lr=9.70e-05]2026-03-10 06:40:38,923 | INFO | [Step 0100] total_suffix_lm_loss=3.9408 | lr=9.70e-05 | train_directions=B_to_A
# Training:  25%|█▏   | 124/500 [05:57<17:19,  2.77s/it, loss=3.7649, lr=9.33e-05]2026-03-10 06:41:47,629 | INFO | [Step 0125] total_suffix_lm_loss=3.7649 | lr=9.33e-05 | train_directions=B_to_A
# Training:  30%|█▍   | 149/500 [07:06<16:07,  2.76s/it, loss=3.6325, lr=8.83e-05]2026-03-10 06:42:56,733 | INFO | [Step 0150] total_suffix_lm_loss=3.6325 | lr=8.83e-05 | train_directions=B_to_A
# Training:  35%|█▋   | 174/500 [08:15<15:00,  2.76s/it, loss=3.7047, lr=8.21e-05]2026-03-10 06:44:05,977 | INFO | [Step 0175] total_suffix_lm_loss=3.7047 | lr=8.21e-05 | train_directions=B_to_A
# Training:  40%|█▉   | 199/500 [09:25<13:54,  2.77s/it, loss=3.8917, lr=7.50e-05]2026-03-10 06:45:15,271 | INFO | [Step 0200] total_suffix_lm_loss=3.8917 | lr=7.50e-05 | train_directions=B_to_A
# Training:  45%|██▏  | 224/500 [10:34<12:45,  2.77s/it, loss=3.8602, lr=6.71e-05]2026-03-10 06:46:24,564 | INFO | [Step 0225] total_suffix_lm_loss=3.8602 | lr=6.71e-05 | train_directions=B_to_A
# Training:  50%|██▍  | 249/500 [11:43<11:33,  2.76s/it, loss=3.9229, lr=5.87e-05]2026-03-10 06:47:33,691 | INFO | [Step 0250] total_suffix_lm_loss=3.9229 | lr=5.87e-05 | train_directions=B_to_A
# Training:  55%|██▋  | 274/500 [12:52<10:23,  2.76s/it, loss=3.6657, lr=5.00e-05]2026-03-10 06:48:43,077 | INFO | [Step 0275] total_suffix_lm_loss=3.6657 | lr=5.00e-05 | train_directions=B_to_A
# Training:  60%|██▉  | 299/500 [14:03<09:22,  2.80s/it, loss=3.6306, lr=4.13e-05]2026-03-10 06:49:53,824 | INFO | [Step 0300] total_suffix_lm_loss=3.6306 | lr=4.13e-05 | train_directions=B_to_A
# Training:  65%|███▏ | 324/500 [15:12<08:06,  2.76s/it, loss=3.6209, lr=3.29e-05]2026-03-10 06:51:02,753 | INFO | [Step 0325] total_suffix_lm_loss=3.6209 | lr=3.29e-05 | train_directions=B_to_A
# Training:  70%|███▍ | 349/500 [16:21<06:56,  2.76s/it, loss=3.6225, lr=2.50e-05]2026-03-10 06:52:11,803 | INFO | [Step 0350] total_suffix_lm_loss=3.6225 | lr=2.50e-05 | train_directions=B_to_A
# Training:  75%|███▋ | 374/500 [17:30<05:50,  2.78s/it, loss=3.5841, lr=1.79e-05]2026-03-10 06:53:20,989 | INFO | [Step 0375] total_suffix_lm_loss=3.5841 | lr=1.79e-05 | train_directions=B_to_A
# Training:  80%|███▉ | 399/500 [18:39<04:38,  2.75s/it, loss=3.7581, lr=1.17e-05]2026-03-10 06:54:30,071 | INFO | [Step 0400] total_suffix_lm_loss=3.7581 | lr=1.17e-05 | train_directions=B_to_A
# Training:  85%|████▏| 424/500 [19:49<03:31,  2.78s/it, loss=3.7334, lr=6.70e-06]2026-03-10 06:55:39,388 | INFO | [Step 0425] total_suffix_lm_loss=3.7334 | lr=6.70e-06 | train_directions=B_to_A
# Training:  90%|████▍| 449/500 [20:58<02:22,  2.79s/it, loss=3.6456, lr=3.02e-06]2026-03-10 06:56:48,599 | INFO | [Step 0450] total_suffix_lm_loss=3.6456 | lr=3.02e-06 | train_directions=B_to_A
# Training:  95%|████▋| 474/500 [22:07<01:11,  2.75s/it, loss=3.5453, lr=7.60e-07]2026-03-10 06:57:57,665 | INFO | [Step 0475] total_suffix_lm_loss=3.5453 | lr=7.60e-07 | train_directions=B_to_A
# Training: 100%|████▉| 499/500 [23:16<00:02,  2.75s/it, loss=3.4967, lr=0.00e+00]2026-03-10 06:59:06,605 | INFO | [Step 0500] total_suffix_lm_loss=3.4967 | lr=0.00e+00 | train_directions=B_to_A
# Training: 100%|█████| 500/500 [23:16<00:00,  2.79s/it, loss=3.4967, lr=0.00e+00]
# 2026-03-10 06:59:12,446 | INFO | [Done] final checkpoint saved to outputs/heterocache_20260310_063538/final_checkpoint.pt
# 2026-03-10 06:59:12,447 | INFO | Saved train log to outputs/heterocache_20260310_063538/train.log
# Saved outputs to outputs/heterocache_20260310_063538
# Final checkpoint: outputs/heterocache_20260310_063538/final_checkpoint.pt

# %%
! cd HeteroCache ; python eval.py heterocache
# Out:
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:441: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# /usr/local/lib/python3.12/dist-packages/transformers/utils/generic.py:309: FutureWarning: `torch.utils._pytree._register_pytree_node` is deprecated. Please use `torch.utils._pytree.register_pytree_node` instead.
#   _torch_pytree._register_pytree_node(
# 2026-03-10 07:01:22,871 | INFO | Starting evaluation
# 2026-03-10 07:01:22,871 | INFO | checkpoint_path=outputs/heterocache_20260310_063538/final_checkpoint.pt
# 2026-03-10 07:01:22,871 | INFO | eval_config={'alg': 'heterocache', 'output_root': 'outputs', 'timestamp': None, 'output_dir': 'outputs/heterocache_20260310_063538', 'checkpoint_path': 'outputs/heterocache_20260310_063538/final_checkpoint.pt', 'config_path': 'outputs/heterocache_20260310_063538/eval_config.json', 'log_filename': 'eval.log', 'log_path': 'outputs/heterocache_20260310_063538/eval.log', 'device': 'cuda', 'batch_size': 1, 'num_workers': 0, 'max_examples_per_dataset': 512, 'seed': 42, 'shuffle_eval_stream': True, 'shuffle_buffer': 10000, 'num_generation_samples_per_dataset': 2}
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/file_download.py:949: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# 2026-03-10 07:01:37,319 | INFO | restored_train_config={'alg': 'heterocache', 'output_root': 'outputs', 'timestamp': '20260310_063538', 'output_dir': 'outputs/heterocache_20260310_063538', 'config_path': 'outputs/heterocache_20260310_063538/train_config.json', 'log_path': 'outputs/heterocache_20260310_063538/train.log', 'checkpoint_path': 'outputs/heterocache_20260310_063538/final_checkpoint.pt', 'model_a_id': 'gpt2', 'model_b_id': 'gpt2-medium', 'max_steps': 500, 'batch_size': 1, 'grad_accum_steps': 16, 'total_tokens': 128, 'prefix_tokens': 64, 'learning_rate': 0.0001, 'weight_decay': 0.01, 'warmup_steps': 50, 'grad_clip_norm': 1.0, 'log_every': 25, 'seed': 42, 'shuffle_buffer': 50000, 'top_layers_to_translate': 12, 'translator_dim': 1024, 'translator_heads': 16, 'translator_depth': 2, 'translator_mlp_ratio': 2, 'train_directions': 'B_to_A', 'device': 'cuda', 'dtype': 'float32'}
# 2026-03-10 07:01:37,319 | INFO | model_A=gpt2
# 2026-03-10 07:01:37,319 | INFO | model_B=gpt2-medium
# 2026-03-10 07:01:37,319 | INFO | top_layers_to_translate=12
# 2026-03-10 07:01:37,319 | INFO | active_directions=['B_to_A']
# 2026-03-10 07:01:37,320 | INFO | translation_mode=replace_top_layers_after_target_forward
# 2026-03-10 07:01:37,320 | INFO | qa_eval_log_path=outputs/heterocache_20260310_063538/eval.log
# 2026-03-10 07:01:37,320 | INFO | Preparing dataloader for BoolQ/validation
# 2026-03-10 07:01:44,658 | INFO | [BoolQ/validation] progress: 50/512 examples
# 2026-03-10 07:01:49,050 | INFO | [BoolQ/validation] progress: 100/512 examples
# 2026-03-10 07:01:53,390 | INFO | [BoolQ/validation] progress: 150/512 examples
# 2026-03-10 07:01:57,734 | INFO | [BoolQ/validation] progress: 200/512 examples
# 2026-03-10 07:02:02,123 | INFO | [BoolQ/validation] progress: 250/512 examples
# 2026-03-10 07:02:06,529 | INFO | [BoolQ/validation] progress: 300/512 examples
# 2026-03-10 07:02:10,911 | INFO | [BoolQ/validation] progress: 350/512 examples
# 2026-03-10 07:02:15,317 | INFO | [BoolQ/validation] progress: 400/512 examples
# 2026-03-10 07:02:19,700 | INFO | [BoolQ/validation] progress: 450/512 examples
# 2026-03-10 07:02:24,110 | INFO | [BoolQ/validation] progress: 500/512 examples
# 2026-03-10 07:02:25,197 | INFO | ===== BoolQ/validation =====
# 2026-03-10 07:02:25,197 | INFO | B_to_A (gpt2-medium -> gpt2) | cosine=0.263331 | accuracy=0.425781 | native_accuracy=0.550781 | count=512
# 2026-03-10 07:02:25,197 | INFO | AVG (weighted over evaluated paths) | cosine=0.263331 | accuracy=0.425781 | native_accuracy=0.550781 | count=512
# 2026-03-10 07:02:25,198 | INFO | ===== SAMPLE QA SCORES: BoolQ/validation =====
# 2026-03-10 07:02:25,953 | INFO | --- Sample 1/2 | BoolQ/validation ---
# 2026-03-10 07:02:25,953 | INFO | prefix(question):
# Question: does ethanol take more energy make that produces
# Answer:
# 2026-03-10 07:02:25,953 | INFO | gold_answer: no
# 2026-03-10 07:02:26,013 | INFO | B_to_A (gpt2-medium -> gpt2) translated_scores: yes=-9.569445 | no=-6.847405 | pred=no | correct=True
# 2026-03-10 07:02:26,013 | INFO | B_to_A (gpt2-medium -> gpt2) native_baseline_scores: yes=-2.161246 | no=-2.937186 | pred=yes | correct=False
# 2026-03-10 07:02:26,041 | INFO | --- Sample 2/2 | BoolQ/validation ---
# 2026-03-10 07:02:26,041 | INFO | prefix(question):
# Question: is house tax and property tax are same
# Answer:
# 2026-03-10 07:02:26,041 | INFO | gold_answer: yes
# 2026-03-10 07:02:26,101 | INFO | B_to_A (gpt2-medium -> gpt2) translated_scores: yes=-9.672253 | no=-6.874509 | pred=no | correct=False
# 2026-03-10 07:02:26,101 | INFO | B_to_A (gpt2-medium -> gpt2) native_baseline_scores: yes=-2.782054 | no=-3.382122 | pred=yes | correct=True
# 2026-03-10 07:02:26,102 | INFO | Preparing dataloader for PubMedQA/pqa_labeled/train
# 2026-03-10 07:02:32,258 | INFO | [PubMedQA/pqa_labeled/train] progress: 50/512 examples
# 2026-03-10 07:02:37,619 | INFO | [PubMedQA/pqa_labeled/train] progress: 100/512 examples
# 2026-03-10 07:02:42,977 | INFO | [PubMedQA/pqa_labeled/train] progress: 150/512 examples
# 2026-03-10 07:02:48,429 | INFO | [PubMedQA/pqa_labeled/train] progress: 200/512 examples
# 2026-03-10 07:02:53,785 | INFO | [PubMedQA/pqa_labeled/train] progress: 250/512 examples
# 2026-03-10 07:02:59,142 | INFO | [PubMedQA/pqa_labeled/train] progress: 300/512 examples
# 2026-03-10 07:03:04,551 | INFO | [PubMedQA/pqa_labeled/train] progress: 350/512 examples
# 2026-03-10 07:03:09,973 | INFO | [PubMedQA/pqa_labeled/train] progress: 400/512 examples
# 2026-03-10 07:03:15,378 | INFO | [PubMedQA/pqa_labeled/train] progress: 450/512 examples
# 2026-03-10 07:03:20,756 | INFO | [PubMedQA/pqa_labeled/train] progress: 500/512 examples
# 2026-03-10 07:03:22,051 | INFO | ===== PubMedQA/pqa_labeled/train =====
# 2026-03-10 07:03:22,051 | INFO | B_to_A (gpt2-medium -> gpt2) | cosine=0.274040 | accuracy=0.343750 | native_accuracy=0.515625 | count=512
# 2026-03-10 07:03:22,051 | INFO | AVG (weighted over evaluated paths) | cosine=0.274040 | accuracy=0.343750 | native_accuracy=0.515625 | count=512
# 2026-03-10 07:03:22,052 | INFO | ===== SAMPLE QA SCORES: PubMedQA/pqa_labeled/train =====
# 2026-03-10 07:03:22,546 | INFO | --- Sample 1/2 | PubMedQA/pqa_labeled/train ---
# 2026-03-10 07:03:22,546 | INFO | prefix(question):
# Question: Do mitochondria play a role in remodelling lace plant leaves during programmed cell death?
# Answer:
# 2026-03-10 07:03:22,546 | INFO | gold_answer: yes
# 2026-03-10 07:03:22,626 | INFO | B_to_A (gpt2-medium -> gpt2) translated_scores: yes=-9.898096 | no=-7.022842 | maybe=-10.174126 | pred=no | correct=False
# 2026-03-10 07:03:22,627 | INFO | B_to_A (gpt2-medium -> gpt2) native_baseline_scores: yes=-7.082840 | no=-7.013420 | maybe=-12.785172 | pred=no | correct=False
# 2026-03-10 07:03:22,655 | INFO | --- Sample 2/2 | PubMedQA/pqa_labeled/train ---
# 2026-03-10 07:03:22,655 | INFO | prefix(question):
# Question: Landolt C and snellen e acuity: differences in strabismus amblyopia?
# Answer:
# 2026-03-10 07:03:22,655 | INFO | gold_answer: no
# 2026-03-10 07:03:22,736 | INFO | B_to_A (gpt2-medium -> gpt2) translated_scores: yes=-9.912158 | no=-7.236206 | maybe=-10.515882 | pred=no | correct=True
# 2026-03-10 07:03:22,736 | INFO | B_to_A (gpt2-medium -> gpt2) native_baseline_scores: yes=-7.976189 | no=-7.186615 | maybe=-11.037727 | pred=no | correct=True
# 2026-03-10 07:03:22,739 | INFO | ===== FINAL SUMMARY =====
# 2026-03-10 07:03:22,739 | INFO | BoolQ/validation | B_to_A(cos=0.263331, acc=0.425781, native_acc=0.550781) | AVG(cos=0.263331, acc=0.425781, native_acc=0.550781)
# 2026-03-10 07:03:22,740 | INFO | PubMedQA/pqa_labeled/train | B_to_A(cos=0.274040, acc=0.343750, native_acc=0.515625) | AVG(cos=0.274040, acc=0.343750, native_acc=0.515625)
# 2026-03-10 07:03:22,740 | INFO | ===== OVERALL AVERAGE ACROSS DATASETS =====
# 2026-03-10 07:03:22,740 | INFO | B_to_A (gpt2-medium -> gpt2) | cosine=0.268685 | accuracy=0.384766 | native_accuracy=0.533203 | count=1024
# 2026-03-10 07:03:22,740 | INFO | AVG (weighted over all datasets and evaluated paths) | cosine=0.268685 | accuracy=0.384766 | native_accuracy=0.533203 | count=1024
# 2026-03-10 07:03:22,740 | INFO | Done. Saved log to outputs/heterocache_20260310_063538/eval.log
# Evaluation log: outputs/heterocache_20260310_063538/eval.log
